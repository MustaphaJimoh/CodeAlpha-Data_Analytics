# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/supermarket_sales.csv")

# First look at the data
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_5311/1298082194.py in <cell line: 0>()
#       4
#       5 # Load dataset
# ----> 6 df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/supermarket_sales.csv")
#       7
#       8 # First look at the data
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# First look at the data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check shape and basic info
print("Dataset Shape:", df.shape)
print("\nColumn Info:")
print(df.info())
print("\nBasic Statistics:")
df.describe()
# Out:
# Dataset Shape: (891, 12)
#
# Column Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Basic Statistics:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
# Check shape and basic info
print("Dataset Shape:", df.shape)
print("\nColumn Info:")
print(df.info())
print("\nBasic Statistics:")
df.describe()
# Out:
# Dataset Shape: (891, 12)
#
# Column Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Basic Statistics:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
# Check missing values
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Survival count
print("Survival Count:")
print(df['Survived'].value_counts())
print("\nSurvival by Gender:")
print(df.groupby('Sex')['Survived'].mean())
print("\nSurvival by Class:")
print(df.groupby('Pclass')['Survived'].mean())
# Out:
# Survival Count:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# Survival by Gender:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
#
# Survival by Class:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# Visualizations
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Survival count
df['Survived'].value_counts().plot(kind='bar', ax=axes[0], color=['red','green'])
axes[0].set_title('Survival Count')
axes[0].set_xticklabels(['Died', 'Survived'], rotation=0)

# Survival by gender
df.groupby('Sex')['Survived'].mean().plot(kind='bar', ax=axes[1], color=['blue','orange'])
axes[1].set_title('Survival Rate by Gender')

# Survival by class
df.groupby('Pclass')['Survived'].mean().plot(kind='bar', ax=axes[2], color='purple')
axes[2].set_title('Survival Rate by Class')

plt.tight_layout()
plt.show()

# %%
# Age distribution of survivors vs non-survivors
plt.figure(figsize=(10, 5))
df[df['Survived']==1]['Age'].dropna().hist(bins=30, alpha=0.7, color='green', label='Survived')
df[df['Survived']==0]['Age'].dropna().hist(bins=30, alpha=0.7, color='red', label='Died')
plt.title('Age Distribution: Survived vs Died')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# Summary of findings
print("""
=== TITANIC EDA - KEY FINDINGS ===

1. Only 38% of passengers survived (342 out of 891)
2. Women had 74% survival rate vs 19% for men
3. 1st Class passengers survived at 63% vs 24% for 3rd Class
4. Age column had 177 missing values, Cabin had 687
5. Most deaths were among passengers aged 20-35
6. Wealth and gender were the strongest survival factors
""")
# Out:
# === TITANIC EDA - KEY FINDINGS ===
#
# 1. Only 38% of passengers survived (342 out of 891)
# 2. Women had 74% survival rate vs 19% for men
# 3. 1st Class passengers survived at 63% vs 24% for 3rd Class
# 4. Age column had 177 missing values, Cabin had 687
# 5. Most deaths were among passengers aged 20-35
# 6. Wealth and gender were the strongest survival factors
